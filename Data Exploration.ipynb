# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("data.csv")
# df = df.drop(columns=['Unnamed: 32'])

# %%
mean_df = df.groupby(['diagnosis']).mean()
mean_df = mean_df.drop(columns=['id'])
mean_df
# Out:
#            radius_mean  texture_mean  perimeter_mean   area_mean  \
# diagnosis
# B            12.146524     17.914762       78.075406  462.790196
# M            17.462830     21.604906      115.365377  978.376415
#
#            smoothness_mean  compactness_mean  concavity_mean  \
# diagnosis
# B                 0.092478          0.080085        0.046058
# M                 0.102898          0.145188        0.160775
#
#            concave points_mean  symmetry_mean  fractal_dimension_mean  ...  \
# diagnosis                                                              ...
# B                     0.025717       0.174186                0.062867  ...
# M                     0.087990       0.192909                0.062680  ...
#
#            radius_worst  texture_worst  perimeter_worst   area_worst  \
# diagnosis
# B             13.379801      23.515070        87.005938   558.899440
# M             21.134811      29.318208       141.370330  1422.286321
#
# ...

# %%
# fig, ax = plt.subplots()
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
mean_df[["perimeter_mean", "perimeter_worst"]].plot(kind="bar")
# perimeter_worst = ax.bar(mean_df.index, mean_df["perimeter_worst"])
# perimeter_mean = ax.bar(mean_df.index, mean_df["perimeter_mean"])
plt.title('Avg. Perimeter for Benign and Malignant Nuclei')
plt.style.use('seaborn-paper')
plt.savefig('images/perimeter.png')

# %%
mean_df[["radius_mean", "radius_worst"]].plot(kind="bar")
# perimeter_worst = ax.bar(mean_df.index, mean_df["perimeter_worst"])
# perimeter_mean = ax.bar(mean_df.index, mean_df["perimeter_mean"])
plt.title('Avg. Radius for Benign and Malignant Nuclei')
plt.style.use('seaborn-notebook')
plt.savefig('images/radius.png')

# %%
mean_df[["texture_mean", "texture_worst"]].plot(kind="bar")
# perimeter_worst = ax.bar(mean_df.index, mean_df["perimeter_worst"])
# perimeter_mean = ax.bar(mean_df.index, mean_df["perimeter_mean"])
plt.title('Avg. Texture for Benign and Malignant Nuclei')
plt.style.use('seaborn-notebook')
plt.savefig('images/texture.png')

# %%
mean_df[["area_mean", "area_worst"]].plot(kind="bar")
# perimeter_worst = ax.bar(mean_df.index, mean_df["perimeter_worst"])
# perimeter_mean = ax.bar(mean_df.index, mean_df["perimeter_mean"])
plt.title('Avg. Area for Benign and Malignant Nuclei')
plt.style.use('seaborn-notebook')
plt.savefig('images/area.png')

# %%
mean_df[["smoothness_mean", "smoothness_worst"]].plot(kind="bar")
# perimeter_worst = ax.bar(mean_df.index, mean_df["perimeter_worst"])
# perimeter_mean = ax.bar(mean_df.index, mean_df["perimeter_mean"])
plt.title('Avg. Smoothness for Benign and Malignant Nuclei')
plt.style.use('seaborn-notebook')
plt.savefig('images/smoothness.png')

# %%
mean_df.columns
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
mean_df[["compactness_mean", "compactness_worst"]].plot(kind="bar")
# perimeter_worst = ax.bar(mean_df.index, mean_df["perimeter_worst"])
# perimeter_mean = ax.bar(mean_df.index, mean_df["perimeter_mean"])
plt.title('Avg. Compactness for Benign and Malignant Nuclei')
plt.style.use('seaborn-notebook')
plt.savefig('images/compactness.png')

# %%
mean_df[["concavity_mean", "concavity_worst"]].plot(kind="bar")
# perimeter_worst = ax.bar(mean_df.index, mean_df["perimeter_worst"])
# perimeter_mean = ax.bar(mean_df.index, mean_df["perimeter_mean"])
plt.title('Avg. Concavity for Benign and Malignant Nuclei')
plt.style.use('seaborn-notebook')
plt.savefig('images/concavity.png')

# %%
mean_df[["concave points_mean", "concave points_worst"]].plot(kind="bar")
# perimeter_worst = ax.bar(mean_df.index, mean_df["perimeter_worst"])
# perimeter_mean = ax.bar(mean_df.index, mean_df["perimeter_mean"])
plt.title('Avg. Concave Points for Benign and Malignant Nuclei')
plt.style.use('seaborn-notebook')
plt.savefig('images/concave_points.png')

# %%
mean_df[["symmetry_mean", "symmetry_worst"]].plot(kind="bar")
# perimeter_worst = ax.bar(mean_df.index, mean_df["perimeter_worst"])
# perimeter_mean = ax.bar(mean_df.index, mean_df["perimeter_mean"])
plt.title('Avg. Symmetry for Benign and Malignant Nuclei')
plt.style.use('seaborn-notebook')
plt.savefig('images/symmetry.png')

# %%
mean_df[["fractal_dimension_mean", "fractal_dimension_worst"]].plot(kind="bar")
# perimeter_worst = ax.bar(mean_df.index, mean_df["perimeter_worst"])
# perimeter_mean = ax.bar(mean_df.index, mean_df["perimeter_mean"])
plt.title('Avg. Fractal Dimension for Benign and Malignant Nuclei')
plt.style.use('seaborn-notebook')
plt.savefig('images/fractal_dimension.png')
